# %%
import numpy as np
from qiskit import *
# %matplotlib inline

circ = QuantumCircuit(3)
circ.h(0)
circ.cx(0, 1)
circ.cx(0, 2)
circ.draw('mpl')

# %% [markdown]
# ![image.png](attachment:40330661-fd08-4ee5-85a7-5875a9f3dd6c.png)

# %% [markdown]
# ابتدا یک محیط پایتون ایجاد کردم موارد گفته شده در پروژه را نصب کردم
# علاوه بر آنها بسته های
#
# pylatexenc و matplotlib
#
# را نیز نصب کردن
# کرنل را اجرا کردم
# جوپیتر را باز کردم و به کرنل وصل شدم و کد را اجرا کردم
